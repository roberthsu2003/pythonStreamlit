# %%
#pin install FinMind
import ffn

stock_no = '2330.TW'
stock_data = ffn.get([stock_no,'1101.TW'],start='2010-01-01')
print(type(stock_data))
display(stock_data)
stock_data.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                 2330tw     1101tw
# Date
# 2010-01-04   41.729416  12.405301
# 2010-01-05   41.472237  12.839305
# 2010-01-06   41.729416  13.110557
# 2010-01-07   41.279343  12.857388
# 2010-01-08   41.150734  12.803136
# ...                ...        ...
# 2023-08-07  558.000000  37.650002
# 2023-08-08  552.000000  37.099998
# 2023-08-09  554.000000  37.150002
# 2023-08-10  551.000000  36.849998
# 2023-08-11  546.000000  37.400002
#
# [3332 rows x 2 columns]
# <Axes: xlabel='Date'>

# %%
#股票報酬率比較
stock_data.rebase().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#最大交易回落(MMD)
stock_data.to_drawdown_series().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock_data.plot_corr_heatmap()
# Out:
# <module 'matplotlib.pyplot' from '/home/vscode/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>
