# %%
import ffn
import matplotlib.pyplot as plt
stock_no1 = '2330.TW'
stock_no2 = '2303.TW'
stock_data = ffn.get([stock_no1,stock_no2],start='2010-01-01')
axes:plt.Axes = stock_data.rebase().plot(figsize=(10, 5))

# %%
stock_data.rebase().plot(figsize=(10, 5))
# Out:
# <Axes: xlabel='Date'>

# %%
returns = stock_data.to_returns().dropna()
returns.hist(figsize=(10, 5))
# Out:
# array([[<Axes: title={'center': '2330tw'}>,
#         <Axes: title={'center': '2303tw'}>]], dtype=object)

# %%
stats = stock_data.calc_stats()
stats.display()
# Out:
# Stat                 2330tw      2303tw
# -------------------  ----------  ----------
# Start                2010-01-04  2010-01-04
# End                  2023-08-11  2023-08-11
# Risk-free rate       0.00%       0.00%
#
# Total Return         1208.43%    402.27%
# Daily Sharpe         0.92        0.55
# Daily Sortino        1.62        1.00
# CAGR                 20.81%      12.60%
# Max Drawdown         -44.80%     -46.23%
# Calmar Ratio         0.46        0.27
#
# MTD                  -3.36%      -3.51%
# 3m                   9.93%       -1.15%
# 6m                   1.20%       -4.26%
# YTD                  22.97%      19.50%
# 1Y                   8.54%       16.63%
# 3Y (ann.)            10.55%      28.86%
# 5Y (ann.)            20.82%      27.62%
# 10Y (ann.)           22.44%      19.15%
# Since Incep. (ann.)  20.81%      12.60%
#
# Daily Sharpe         0.92        0.55
# Daily Sortino        1.62        1.00
# Daily Mean (ann.)    22.44%      17.07%
# ...
