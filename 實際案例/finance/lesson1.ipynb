# %%
#pin install FinMind
import ffn

stock_no = '2330.TW'
stock_data = ffn.get([stock_no,'1101.TW'],start='2010-01-01',end='2010-12-31')
print(type(stock_data))
display(stock_data)
stock_data.plot()
# Out:
# <class 'pandas.core.frame.DataFrame'>
#                2330tw     1101tw
# Date
# 2010-01-04  41.729416  12.405302
# 2010-01-05  41.472233  12.839304
# 2010-01-06  41.729416  13.110561
# 2010-01-07  41.279335  12.857387
# 2010-01-08  41.150745  12.803139
# ...               ...        ...
# 2010-12-24  47.861290  12.793210
# 2010-12-27  47.793690  12.656490
# 2010-12-28  47.928890  12.597895
# 2010-12-29  47.726093  12.676022
# 2010-12-30  47.726093  12.676022
#
# [249 rows x 2 columns]
# <Axes: xlabel='Date'>

# %%
#股票報酬率比較
stock_data.rebase().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#最大交易回落(MMD)
stock_data.to_drawdown_series().plot()
# Out:
# <Axes: xlabel='Date'>

# %%
stock_data.plot_corr_heatmap()
# Out:
# <module 'matplotlib.pyplot' from '/home/vscode/.local/lib/python3.10/site-packages/matplotlib/pyplot.py'>
